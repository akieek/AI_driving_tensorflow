# %% [markdown]
# これはwindows11proで実行する用のファイルです。[CUDA==11.8 GPU_driver==531.41 cuDNN==8.9.7.29]
# [CUDA==11.2.2 GPU_driver==546.33 cuDNN==8.1]

# %%
# インポート
import os
import glob
import argparse
import numpy as np
import zipfile
import time
import datetime

import sklearn  
from sklearn.model_selection import train_test_split

import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import cv2

import tensorflow as tf

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Input, Conv2D
from tensorflow.keras import optimizers

# from common_flags import FLAGS
from tensorflow.keras.utils import plot_model, to_categorical

#package modul version 表示

print("tensorflow: ", tf.__version__)# 2023/01/13 時点 ver. 2.9.2
print("numpy: ", np.__version__)
print("pandas: ", pd.__version__)
print("sklearn (for train_test_split): ", sklearn.__version__)
print("matplotlib (for pyplot): ", matplotlib.__version__)
print("opencv (cv2): ", cv2.__version__)
print("tensorflow-gpu: ", tf.test.is_built_with_cuda())

# !python -V
# Out:
# tensorflow:  2.9.2
# numpy:  1.24.3
# pandas:  1.5.3
# sklearn (for train_test_split):  1.2.2
# matplotlib (for pyplot):  3.7.1
# opencv (cv2):  4.8.0
# tensorflow-gpu:  True
# Python 3.8.18

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # メモリ成長を有効にする
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %%
# 訓練用ニューラルネットワーク定義
def cnn(input_shape):
    drop = 0.5
    # Input
    img_input = Input(shape=(input_shape), name='input')
    x1 = Conv2D(24, (5,5), strides=(2,2), activation='relu', name="conv2d_1")(img_input)
    x2 = Conv2D(32, (5,5), strides=(2,2), activation='relu', name="conv2d_2")(x1)
    x3 = Conv2D(64, (5,5), strides=(2,2), activation='relu', name="conv2d_3")(x2)
    x4 = Conv2D(64, (3,3), strides=(2,2), activation='relu', name="conv2d_4")(x3)
    x5 = Conv2D(64, (3,3), strides=(1,1), activation='relu', name="conv2d_5")(x4)



    ##全結合層の定義
    x6 = Flatten(name='flattened')(x5)
    x7 = Dense(100, activation='relu', name="fc_1")(x6)
    x8 = Dropout(0.5 , name="Dropout_1")(x7)

    x9 = Dense(50, activation='relu', name="fc_2")(x8)
    x10 = Dropout(0.5, name="Dropout_2")(x9)

    x11 = Dense(20, activation='relu', name="fc_3")(x6)
    x12 = Dropout(0.5, name="Dropout_3")(x11)

    ##出力層
    output1 = Dense(1, activation='linear', name='output1')(x10)
    output2 = Dense(1, activation='linear', name='output2')(x12)

   ##出力２に対して入力Ⅰの定義 output1 steer output2 throttle
    model = Model(inputs=[img_input], outputs=[output1, output2])

    return model

# %%
#グラフを2つに分けたプログラム
def plot_history_loss(history):
    # ステアリング損失のグラフをプロット
    plt.figure()
    plt.plot(history.history['output1_loss'], label='steer loss for trainig')
    plt.plot(history.history['val_output1_loss'], label='steer loss for vlidation')
    plt.xlabel('Epochs', fontsize=18)
    plt.ylabel('target steer loss',fontsize=18)
    plt.legend(loc='best',fontsize=18)
    #　軸の目盛り
    plt.xticks(fontsize=18)
    plt.yticks(fontsize=18)
    
    plt.savefig('./16_steering_loss.png')
    plt.show()
    plt.close()

    # スロットル損失のグラフをプロット
    plt.figure()
    plt.plot(history.history['output2_loss'], label=('throttle loss for Trainig'))
    plt.plot(history.history['val_output2_loss'], label='throttle loss for validation')
    plt.xlabel('Epochs',fontsize=18)
    plt.ylabel('target throttle loss',fontsize=18)
    plt.legend(loc='best',fontsize=18)
    #　軸の目盛り
    plt.xticks(fontsize=18)
    plt.yticks(fontsize=18)
    plt.savefig('./16_throttle_loss.png')
    plt.show()
    plt.close()

# %%
#グラフを一つにまとめた
def plot_history_loss(history):
    plt.figure(figsize=(10, 6))

    # ステアリング損失（トレーニングとバリデーション）
    plt.plot(history.history['output1_loss'], label='steer loss for training', color='blue')
    plt.plot(history.history['val_output1_loss'], label='steer loss for validation', color='cyan')

    # スロットル損失（トレーニングとバリデーション）
    plt.plot(history.history['output2_loss'], label='throttle loss  for training', color='red')
    plt.plot(history.history['val_output2_loss'], label='throttle loss for validation', color='magenta')

    # グラフの設定
    plt.xlabel('Epochs', fontsize=22)
    plt.ylabel('loss', fontsize=22)
    plt.legend(loc='best', fontsize=22)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.grid(True)

    plt.savefig('./combined_loss.png')
    plt.show()
    plt.close()

# plot_combined_loss(history) # 実際のhistoryオブジェクトを使用して呼び出す

# %%
# 訓練時の画像サイズ
image_width = 160         #ピクセル
image_height = 120

# 訓練画像を読み込む関数
def load_images(input_dir, X, Y, Z):
    img_list = pd.read_csv(input_dir + '/list2.txt', header=None, delim_whitespace=True)
    image_path = input_dir + '/images/' + img_list[0]

    # 画像データの読み込み
    for index, file_name in enumerate(image_path):
        image = cv2.imread(file_name)
        resize_image = cv2.resize(image, (image_width, image_height))
        data = np.asarray(resize_image)
        X.append(data)
        Y.append(img_list[1][index])
        Z.append(img_list[2][index])
    return X, Y, Z

# %%
# メイン関数の定義　callbackがあるバージョン
def _main():
    X = []
    Y = []
    Z = []
    X, Y, Z =load_images("./6_image_data", X, Y, Z) # images_dataの読み込み
    X, Y, Z=load_images("./7_image_data", X, Y, Z) # images_dataの読み込み
    X, Y, Z=load_images("./8_image_data", X, Y, Z) # images_dataの読み込み
    X, Y, Z=load_images("./9_image_data", X, Y, Z) # images_dataの読み込み


    ##Yに正解ラベル（steer）
    ##Zに正解ラベル(throttle)
    #正規化
    X = np.array(X)
    Y = np.array(Y)
    Z = np.array(Z)

    #画像データを0から1の範囲に変換 これを正規化という画像値は0~255の値をとる
    X = X.astype('float32')
    X = X / 255.0
    # 正解データ（steer）の微調整
    Y = Y.astype('float32')
    # 正解データ（thorottle）の微調整
    Z = Z.astype('float32')

    # 学習用データとテストデータ
    X_train, X_test, Y_train, Y_test, Z_train, Z_test = train_test_split(X, Y, Z, test_size=0.20) #0.20なら20%がテストデータ

    # CNNとDNNの構築
    #shapeをCNNの入力に定義
    shape = X_train.shape[1:]
    #1行の行列
    model = cnn(shape)

    # ハイパーパラメータ
    decay = 1e-6
    lr = 1e-3
    batch_size = 64
    epochs = 500
    loss_weights = [1,1]

    #コールバックの設定
    early_stpping_callback = tf.keras.callbacks.EarlyStopping(
        monitor ='val_loss',
        patience = 20,
        verbose = 1,
        mode = 'min',
        restore_best_weights = True
    )

    # コンパイル
    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = lr, decay = decay),
                loss={'output1': tf.keras.losses.huber,
                      'output2': tf.keras.losses.huber},
                loss_weights = loss_weights,
                )


    # 訓練
    history = model.fit(x =  X_train,
                        y = {'output1': Y_train, 'output2': Z_train},
                        batch_size = batch_size,
                        epochs = epochs,
                        verbose = 1,
                        validation_data = ({'input': X_test}, {'output1': Y_test, 'output2': Z_test}),
                        callbacks = [early_stpping_callback],
                       )

    # モデルの保存
    model.save('./15Stopping_model.h5')

    # 評価 & 評価結果出力
    #print(model.evaluate(X_test, {'output1': Y_test, 'output2': Z_test}))

    # モデルの図示化
    plot_model(model, to_file='./15Stopping_model.png', show_shapes=True)

    # 評価 & 評価結果出力
    #print(model.evaluate(X_test, {'output1': Y_test, 'output2': Z_test}))

    # show result graph
    plot_history_loss(history)

# %%
_main()
# Out:
# Epoch 1/500
# 673/673 [==============================] - 8s 8ms/step - loss: 7.9797 - output1_loss: 5.8421 - output2_loss: 2.1377 - val_loss: 4.8605 - val_output1_loss: 4.2191 - val_output2_loss: 0.6414
# Epoch 2/500
# 673/673 [==============================] - 5s 7ms/step - loss: 6.3757 - output1_loss: 4.8972 - output2_loss: 1.4785 - val_loss: 4.2686 - val_output1_loss: 3.9224 - val_output2_loss: 0.3461
# Epoch 3/500
# 673/673 [==============================] - 5s 7ms/step - loss: 5.9145 - output1_loss: 4.5725 - output2_loss: 1.3420 - val_loss: 4.1794 - val_output1_loss: 3.6716 - val_output2_loss: 0.5078
# Epoch 4/500
# 673/673 [==============================] - 5s 7ms/step - loss: 5.5479 - output1_loss: 4.2679 - output2_loss: 1.2799 - val_loss: 3.7517 - val_output1_loss: 3.4925 - val_output2_loss: 0.2591
# Epoch 5/500
# 673/673 [==============================] - 5s 7ms/step - loss: 5.3338 - output1_loss: 4.1011 - output2_loss: 1.2327 - val_loss: 4.0672 - val_output1_loss: 3.4222 - val_output2_loss: 0.6449
# Epoch 6/500
# 673/673 [==============================] - 5s 7ms/step - loss: 5.0993 - output1_loss: 3.9152 - output2_loss: 1.1841 - val_loss: 4.0190 - val_output1_loss: 3.2611 - val_output2_loss: 0.7579
# Epoch 7/500
# 673/673 [==============================] - 5s 7ms/step - loss: 4.8893 - output1_loss: 3.7675 - output2_loss: 1.1218 - val_loss: 3.3165 - val_output1_loss: 2.9914 - val_output2_loss: 0.3251
# Epoch 8/500
# 673/673 [==============================] - 5s 7ms/step - loss: 4.7719 - output1_loss: 3.6689 - output2_loss: 1.1030 - val_loss: 3.5818 - val_output1_loss: 3.1109 - val_output2_loss: 0.4709
# Epoch 9/500
# 673/673 [==============================] - 5s 7ms/step - loss: 4.6018 - output1_loss: 3.5440 - output2_loss: 1.0579 - val_loss: 3.2815 - val_output1_loss: 2.8784 - val_output2_loss: 0.4032
# Epoch 10/500
# 673/673 [==============================] - 5s 7ms/step - loss: 4.4126 - output1_loss: 3.4162 - output2_loss: 0.9964 - val_loss: 3.1291 - val_output1_loss: 2.8634 - val_output2_loss: 0.2658
# Epoch 11/500
# 673/673 [==============================] - 5s 7ms/step - loss: 4.3146 - output1_loss: 3.3561 - output2_loss: 0.9585 - val_loss: 2.7157 - val_output1_loss: 2.5680 - val_output2_loss: 0.1477
# Epoch 12/500
# 673/673 [==============================] - 5s 7ms/step - loss: 4.1623 - output1_loss: 3.2542 - output2_loss: 0.9082 - val_loss: 2.9860 - val_output1_loss: 2.6267 - val_output2_loss: 0.3593
# Epoch 13/500
# 673/673 [==============================] - 5s 7ms/step - loss: 4.0457 - output1_loss: 3.1918 - output2_loss: 0.8539 - val_loss: 2.8916 - val_output1_loss: 2.6055 - val_output2_loss: 0.2860
# Epoch 14/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.9221 - output1_loss: 3.1190 - output2_loss: 0.8031 - val_loss: 2.5940 - val_output1_loss: 2.4133 - val_output2_loss: 0.1807
# Epoch 15/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.8029 - output1_loss: 3.0607 - output2_loss: 0.7422 - val_loss: 2.6935 - val_output1_loss: 2.4799 - val_output2_loss: 0.2136
# Epoch 16/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.7371 - output1_loss: 3.0283 - output2_loss: 0.7088 - val_loss: 2.5300 - val_output1_loss: 2.2992 - val_output2_loss: 0.2308
# Epoch 17/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.6442 - output1_loss: 2.9427 - output2_loss: 0.7015 - val_loss: 2.4563 - val_output1_loss: 2.3227 - val_output2_loss: 0.1336
# Epoch 18/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.5931 - output1_loss: 2.9005 - output2_loss: 0.6926 - val_loss: 2.4480 - val_output1_loss: 2.3001 - val_output2_loss: 0.1480
# Epoch 19/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.5423 - output1_loss: 2.8578 - output2_loss: 0.6845 - val_loss: 2.3220 - val_output1_loss: 2.2318 - val_output2_loss: 0.0902
# Epoch 20/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.4482 - output1_loss: 2.7995 - output2_loss: 0.6487 - val_loss: 2.4134 - val_output1_loss: 2.1777 - val_output2_loss: 0.2358
# Epoch 21/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.3994 - output1_loss: 2.7630 - output2_loss: 0.6364 - val_loss: 2.4494 - val_output1_loss: 2.2260 - val_output2_loss: 0.2233
# Epoch 22/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.3867 - output1_loss: 2.7452 - output2_loss: 0.6414 - val_loss: 2.6992 - val_output1_loss: 2.4806 - val_output2_loss: 0.2187
# Epoch 23/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.3298 - output1_loss: 2.6999 - output2_loss: 0.6299 - val_loss: 2.4409 - val_output1_loss: 2.2790 - val_output2_loss: 0.1619
# Epoch 24/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.3004 - output1_loss: 2.6694 - output2_loss: 0.6310 - val_loss: 2.5493 - val_output1_loss: 2.3330 - val_output2_loss: 0.2163
# Epoch 25/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.2992 - output1_loss: 2.6681 - output2_loss: 0.6310 - val_loss: 2.2934 - val_output1_loss: 2.1206 - val_output2_loss: 0.1728
# Epoch 26/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.2234 - output1_loss: 2.5987 - output2_loss: 0.6247 - val_loss: 2.3109 - val_output1_loss: 2.1235 - val_output2_loss: 0.1874
# Epoch 27/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.2315 - output1_loss: 2.6068 - output2_loss: 0.6246 - val_loss: 2.1889 - val_output1_loss: 2.0595 - val_output2_loss: 0.1294
# Epoch 28/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.1727 - output1_loss: 2.5546 - output2_loss: 0.6181 - val_loss: 2.4122 - val_output1_loss: 2.2300 - val_output2_loss: 0.1823
# Epoch 29/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.1822 - output1_loss: 2.5609 - output2_loss: 0.6213 - val_loss: 2.3257 - val_output1_loss: 2.1744 - val_output2_loss: 0.1513
# Epoch 30/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.1409 - output1_loss: 2.5298 - output2_loss: 0.6111 - val_loss: 2.2492 - val_output1_loss: 2.0431 - val_output2_loss: 0.2060
# Epoch 31/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.1210 - output1_loss: 2.5030 - output2_loss: 0.6181 - val_loss: 2.1586 - val_output1_loss: 2.0603 - val_output2_loss: 0.0982
# Epoch 32/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.1022 - output1_loss: 2.4911 - output2_loss: 0.6112 - val_loss: 2.1939 - val_output1_loss: 2.0649 - val_output2_loss: 0.1290
# Epoch 33/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.0486 - output1_loss: 2.4441 - output2_loss: 0.6044 - val_loss: 2.2815 - val_output1_loss: 2.0654 - val_output2_loss: 0.2162
# Epoch 34/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.0389 - output1_loss: 2.4335 - output2_loss: 0.6054 - val_loss: 2.3262 - val_output1_loss: 2.0718 - val_output2_loss: 0.2544
# Epoch 35/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.0696 - output1_loss: 2.4631 - output2_loss: 0.6065 - val_loss: 2.3033 - val_output1_loss: 2.0947 - val_output2_loss: 0.2086
# Epoch 36/500
# 673/673 [==============================] - 5s 7ms/step - loss: 3.0189 - output1_loss: 2.4152 - output2_loss: 0.6037 - val_loss: 2.1821 - val_output1_loss: 2.0398 - val_output2_loss: 0.1423
# Epoch 37/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.9839 - output1_loss: 2.3787 - output2_loss: 0.6052 - val_loss: 2.2108 - val_output1_loss: 2.0035 - val_output2_loss: 0.2073
# Epoch 38/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.9792 - output1_loss: 2.3733 - output2_loss: 0.6060 - val_loss: 2.0656 - val_output1_loss: 1.9613 - val_output2_loss: 0.1043
# Epoch 39/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.9684 - output1_loss: 2.3685 - output2_loss: 0.6000 - val_loss: 2.1003 - val_output1_loss: 1.9465 - val_output2_loss: 0.1538
# Epoch 40/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.9611 - output1_loss: 2.3573 - output2_loss: 0.6038 - val_loss: 2.1424 - val_output1_loss: 1.9814 - val_output2_loss: 0.1610
# Epoch 41/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.9323 - output1_loss: 2.3307 - output2_loss: 0.6016 - val_loss: 2.1026 - val_output1_loss: 1.9650 - val_output2_loss: 0.1377
# Epoch 42/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.9174 - output1_loss: 2.3136 - output2_loss: 0.6038 - val_loss: 2.0481 - val_output1_loss: 1.9524 - val_output2_loss: 0.0957
# Epoch 43/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.8997 - output1_loss: 2.3039 - output2_loss: 0.5957 - val_loss: 2.1293 - val_output1_loss: 1.9867 - val_output2_loss: 0.1426
# Epoch 44/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.9043 - output1_loss: 2.3029 - output2_loss: 0.6013 - val_loss: 2.0892 - val_output1_loss: 1.9168 - val_output2_loss: 0.1724
# Epoch 45/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.9079 - output1_loss: 2.3121 - output2_loss: 0.5958 - val_loss: 2.4920 - val_output1_loss: 2.1498 - val_output2_loss: 0.3422
# Epoch 46/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.8886 - output1_loss: 2.2947 - output2_loss: 0.5939 - val_loss: 2.0251 - val_output1_loss: 1.9156 - val_output2_loss: 0.1096
# Epoch 47/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.8642 - output1_loss: 2.2699 - output2_loss: 0.5944 - val_loss: 2.2940 - val_output1_loss: 2.0690 - val_output2_loss: 0.2250
# Epoch 48/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.8462 - output1_loss: 2.2506 - output2_loss: 0.5956 - val_loss: 2.4851 - val_output1_loss: 2.1467 - val_output2_loss: 0.3383
# Epoch 49/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.8550 - output1_loss: 2.2616 - output2_loss: 0.5935 - val_loss: 2.2082 - val_output1_loss: 2.0503 - val_output2_loss: 0.1578
# Epoch 50/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.8400 - output1_loss: 2.2456 - output2_loss: 0.5944 - val_loss: 2.1900 - val_output1_loss: 1.9719 - val_output2_loss: 0.2182
# Epoch 51/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.8189 - output1_loss: 2.2353 - output2_loss: 0.5836 - val_loss: 2.1415 - val_output1_loss: 1.9844 - val_output2_loss: 0.1570
# Epoch 52/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.8122 - output1_loss: 2.2461 - output2_loss: 0.5661 - val_loss: 2.1162 - val_output1_loss: 1.9396 - val_output2_loss: 0.1765
# Epoch 53/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.7409 - output1_loss: 2.1860 - output2_loss: 0.5549 - val_loss: 2.2406 - val_output1_loss: 2.0999 - val_output2_loss: 0.1407
# Epoch 54/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.7597 - output1_loss: 2.2158 - output2_loss: 0.5440 - val_loss: 2.0007 - val_output1_loss: 1.8655 - val_output2_loss: 0.1352
# Epoch 55/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.7192 - output1_loss: 2.1900 - output2_loss: 0.5292 - val_loss: 2.0331 - val_output1_loss: 1.8449 - val_output2_loss: 0.1882
# Epoch 56/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.7213 - output1_loss: 2.1936 - output2_loss: 0.5277 - val_loss: 2.0222 - val_output1_loss: 1.8887 - val_output2_loss: 0.1335
# Epoch 57/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.7160 - output1_loss: 2.1858 - output2_loss: 0.5303 - val_loss: 1.9538 - val_output1_loss: 1.8624 - val_output2_loss: 0.0914
# Epoch 58/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.7257 - output1_loss: 2.1997 - output2_loss: 0.5260 - val_loss: 2.0709 - val_output1_loss: 1.9628 - val_output2_loss: 0.1081
# Epoch 59/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.7077 - output1_loss: 2.1738 - output2_loss: 0.5339 - val_loss: 2.0901 - val_output1_loss: 1.8899 - val_output2_loss: 0.2002
# Epoch 60/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.7026 - output1_loss: 2.1725 - output2_loss: 0.5301 - val_loss: 2.0652 - val_output1_loss: 1.8332 - val_output2_loss: 0.2321
# Epoch 61/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.7099 - output1_loss: 2.1775 - output2_loss: 0.5324 - val_loss: 1.9175 - val_output1_loss: 1.8090 - val_output2_loss: 0.1085
# Epoch 62/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.6693 - output1_loss: 2.1396 - output2_loss: 0.5297 - val_loss: 1.9118 - val_output1_loss: 1.8050 - val_output2_loss: 0.1069
# Epoch 63/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.6654 - output1_loss: 2.1356 - output2_loss: 0.5298 - val_loss: 2.0514 - val_output1_loss: 1.8863 - val_output2_loss: 0.1651
# Epoch 64/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.6579 - output1_loss: 2.1324 - output2_loss: 0.5255 - val_loss: 2.0468 - val_output1_loss: 1.9204 - val_output2_loss: 0.1263
# Epoch 65/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.6774 - output1_loss: 2.1490 - output2_loss: 0.5284 - val_loss: 2.0369 - val_output1_loss: 1.8947 - val_output2_loss: 0.1422
# Epoch 66/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.6515 - output1_loss: 2.1262 - output2_loss: 0.5253 - val_loss: 1.9997 - val_output1_loss: 1.8989 - val_output2_loss: 0.1008
# Epoch 67/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.6312 - output1_loss: 2.1058 - output2_loss: 0.5254 - val_loss: 1.9416 - val_output1_loss: 1.7794 - val_output2_loss: 0.1623
# Epoch 68/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.6413 - output1_loss: 2.1191 - output2_loss: 0.5222 - val_loss: 1.9157 - val_output1_loss: 1.8127 - val_output2_loss: 0.1031
# Epoch 69/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.6132 - output1_loss: 2.0934 - output2_loss: 0.5198 - val_loss: 2.1132 - val_output1_loss: 1.9020 - val_output2_loss: 0.2113
# Epoch 70/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.6262 - output1_loss: 2.1008 - output2_loss: 0.5255 - val_loss: 1.8661 - val_output1_loss: 1.7767 - val_output2_loss: 0.0894
# Epoch 71/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.6036 - output1_loss: 2.0823 - output2_loss: 0.5212 - val_loss: 2.0042 - val_output1_loss: 1.7767 - val_output2_loss: 0.2274
# Epoch 72/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.6275 - output1_loss: 2.0983 - output2_loss: 0.5292 - val_loss: 2.0764 - val_output1_loss: 1.8286 - val_output2_loss: 0.2478
# Epoch 73/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.6168 - output1_loss: 2.0896 - output2_loss: 0.5272 - val_loss: 1.8514 - val_output1_loss: 1.7783 - val_output2_loss: 0.0731
# Epoch 74/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.6225 - output1_loss: 2.0923 - output2_loss: 0.5303 - val_loss: 2.0407 - val_output1_loss: 1.9535 - val_output2_loss: 0.0872
# Epoch 75/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.6124 - output1_loss: 2.0900 - output2_loss: 0.5223 - val_loss: 1.9737 - val_output1_loss: 1.8556 - val_output2_loss: 0.1181
# Epoch 76/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5879 - output1_loss: 2.0685 - output2_loss: 0.5194 - val_loss: 2.0539 - val_output1_loss: 1.8532 - val_output2_loss: 0.2007
# Epoch 77/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5821 - output1_loss: 2.0548 - output2_loss: 0.5274 - val_loss: 2.0100 - val_output1_loss: 1.9169 - val_output2_loss: 0.0931
# Epoch 78/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5824 - output1_loss: 2.0616 - output2_loss: 0.5208 - val_loss: 1.8973 - val_output1_loss: 1.7471 - val_output2_loss: 0.1502
# Epoch 79/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5927 - output1_loss: 2.0681 - output2_loss: 0.5247 - val_loss: 1.8406 - val_output1_loss: 1.7409 - val_output2_loss: 0.0996
# Epoch 80/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5981 - output1_loss: 2.0742 - output2_loss: 0.5239 - val_loss: 1.8331 - val_output1_loss: 1.7701 - val_output2_loss: 0.0630
# Epoch 81/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.6019 - output1_loss: 2.0772 - output2_loss: 0.5247 - val_loss: 1.9708 - val_output1_loss: 1.7645 - val_output2_loss: 0.2064
# Epoch 82/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5635 - output1_loss: 2.0450 - output2_loss: 0.5185 - val_loss: 2.1886 - val_output1_loss: 1.9662 - val_output2_loss: 0.2224
# Epoch 83/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5585 - output1_loss: 2.0372 - output2_loss: 0.5213 - val_loss: 1.9431 - val_output1_loss: 1.8194 - val_output2_loss: 0.1238
# Epoch 84/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5617 - output1_loss: 2.0426 - output2_loss: 0.5191 - val_loss: 1.9123 - val_output1_loss: 1.8050 - val_output2_loss: 0.1073
# Epoch 85/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5581 - output1_loss: 2.0332 - output2_loss: 0.5250 - val_loss: 1.9769 - val_output1_loss: 1.8364 - val_output2_loss: 0.1405
# Epoch 86/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5660 - output1_loss: 2.0397 - output2_loss: 0.5263 - val_loss: 1.9422 - val_output1_loss: 1.8398 - val_output2_loss: 0.1025
# Epoch 87/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5542 - output1_loss: 2.0371 - output2_loss: 0.5171 - val_loss: 2.0119 - val_output1_loss: 1.9020 - val_output2_loss: 0.1099
# Epoch 88/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5233 - output1_loss: 2.0064 - output2_loss: 0.5169 - val_loss: 1.9505 - val_output1_loss: 1.8149 - val_output2_loss: 0.1356
# Epoch 89/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5539 - output1_loss: 2.0306 - output2_loss: 0.5233 - val_loss: 1.8573 - val_output1_loss: 1.7190 - val_output2_loss: 0.1383
# Epoch 90/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5432 - output1_loss: 2.0197 - output2_loss: 0.5235 - val_loss: 1.8278 - val_output1_loss: 1.7198 - val_output2_loss: 0.1081
# Epoch 91/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5265 - output1_loss: 2.0039 - output2_loss: 0.5226 - val_loss: 1.8937 - val_output1_loss: 1.7905 - val_output2_loss: 0.1033
# Epoch 92/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5484 - output1_loss: 2.0264 - output2_loss: 0.5220 - val_loss: 1.8602 - val_output1_loss: 1.7808 - val_output2_loss: 0.0794
# Epoch 93/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5077 - output1_loss: 1.9859 - output2_loss: 0.5218 - val_loss: 1.8549 - val_output1_loss: 1.7525 - val_output2_loss: 0.1024
# Epoch 94/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5252 - output1_loss: 2.0082 - output2_loss: 0.5169 - val_loss: 1.8186 - val_output1_loss: 1.7396 - val_output2_loss: 0.0790
# Epoch 95/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5192 - output1_loss: 1.9984 - output2_loss: 0.5209 - val_loss: 2.0376 - val_output1_loss: 1.8413 - val_output2_loss: 0.1962
# Epoch 96/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5144 - output1_loss: 1.9913 - output2_loss: 0.5231 - val_loss: 1.9510 - val_output1_loss: 1.7646 - val_output2_loss: 0.1864
# Epoch 97/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5205 - output1_loss: 1.9946 - output2_loss: 0.5259 - val_loss: 1.9058 - val_output1_loss: 1.7004 - val_output2_loss: 0.2054
# Epoch 98/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4949 - output1_loss: 1.9687 - output2_loss: 0.5262 - val_loss: 1.9213 - val_output1_loss: 1.8413 - val_output2_loss: 0.0800
# Epoch 99/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5007 - output1_loss: 1.9800 - output2_loss: 0.5206 - val_loss: 1.9200 - val_output1_loss: 1.7541 - val_output2_loss: 0.1659
# Epoch 100/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4927 - output1_loss: 1.9722 - output2_loss: 0.5204 - val_loss: 1.9486 - val_output1_loss: 1.8205 - val_output2_loss: 0.1281
# Epoch 101/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4993 - output1_loss: 1.9785 - output2_loss: 0.5208 - val_loss: 1.8343 - val_output1_loss: 1.6995 - val_output2_loss: 0.1348
# Epoch 102/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4670 - output1_loss: 1.9489 - output2_loss: 0.5181 - val_loss: 1.8062 - val_output1_loss: 1.7394 - val_output2_loss: 0.0667
# Epoch 103/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.5005 - output1_loss: 1.9808 - output2_loss: 0.5197 - val_loss: 1.8266 - val_output1_loss: 1.6797 - val_output2_loss: 0.1469
# Epoch 104/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4849 - output1_loss: 1.9694 - output2_loss: 0.5155 - val_loss: 1.9003 - val_output1_loss: 1.7713 - val_output2_loss: 0.1290
# Epoch 105/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4810 - output1_loss: 1.9610 - output2_loss: 0.5200 - val_loss: 1.8600 - val_output1_loss: 1.7535 - val_output2_loss: 0.1065
# Epoch 106/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4759 - output1_loss: 1.9557 - output2_loss: 0.5201 - val_loss: 1.8438 - val_output1_loss: 1.7496 - val_output2_loss: 0.0942
# Epoch 107/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4983 - output1_loss: 1.9743 - output2_loss: 0.5241 - val_loss: 1.7707 - val_output1_loss: 1.6757 - val_output2_loss: 0.0950
# Epoch 108/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4925 - output1_loss: 1.9745 - output2_loss: 0.5180 - val_loss: 1.9255 - val_output1_loss: 1.7579 - val_output2_loss: 0.1676
# Epoch 109/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4973 - output1_loss: 1.9758 - output2_loss: 0.5215 - val_loss: 1.9593 - val_output1_loss: 1.8112 - val_output2_loss: 0.1481
# Epoch 110/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4761 - output1_loss: 1.9552 - output2_loss: 0.5209 - val_loss: 1.9107 - val_output1_loss: 1.7817 - val_output2_loss: 0.1290
# Epoch 111/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4721 - output1_loss: 1.9521 - output2_loss: 0.5200 - val_loss: 1.8392 - val_output1_loss: 1.7344 - val_output2_loss: 0.1048
# Epoch 112/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4871 - output1_loss: 1.9571 - output2_loss: 0.5300 - val_loss: 1.8407 - val_output1_loss: 1.7098 - val_output2_loss: 0.1309
# Epoch 113/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4530 - output1_loss: 1.9332 - output2_loss: 0.5198 - val_loss: 1.9356 - val_output1_loss: 1.7759 - val_output2_loss: 0.1598
# Epoch 114/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4735 - output1_loss: 1.9492 - output2_loss: 0.5243 - val_loss: 1.8515 - val_output1_loss: 1.7356 - val_output2_loss: 0.1159
# Epoch 115/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4579 - output1_loss: 1.9367 - output2_loss: 0.5212 - val_loss: 1.7598 - val_output1_loss: 1.6959 - val_output2_loss: 0.0640
# Epoch 116/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4818 - output1_loss: 1.9506 - output2_loss: 0.5312 - val_loss: 1.9232 - val_output1_loss: 1.7822 - val_output2_loss: 0.1411
# Epoch 117/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4713 - output1_loss: 1.9528 - output2_loss: 0.5186 - val_loss: 1.7661 - val_output1_loss: 1.6800 - val_output2_loss: 0.0862
# Epoch 118/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4511 - output1_loss: 1.9290 - output2_loss: 0.5221 - val_loss: 1.9614 - val_output1_loss: 1.8524 - val_output2_loss: 0.1090
# Epoch 119/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4443 - output1_loss: 1.9215 - output2_loss: 0.5228 - val_loss: 1.8209 - val_output1_loss: 1.7162 - val_output2_loss: 0.1047
# Epoch 120/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4423 - output1_loss: 1.9140 - output2_loss: 0.5283 - val_loss: 1.8712 - val_output1_loss: 1.6785 - val_output2_loss: 0.1926
# Epoch 121/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4543 - output1_loss: 1.9387 - output2_loss: 0.5156 - val_loss: 1.9127 - val_output1_loss: 1.8119 - val_output2_loss: 0.1008
# Epoch 122/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4509 - output1_loss: 1.9296 - output2_loss: 0.5213 - val_loss: 1.8161 - val_output1_loss: 1.6794 - val_output2_loss: 0.1367
# Epoch 123/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4460 - output1_loss: 1.9220 - output2_loss: 0.5241 - val_loss: 1.9072 - val_output1_loss: 1.7628 - val_output2_loss: 0.1443
# Epoch 124/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4296 - output1_loss: 1.9099 - output2_loss: 0.5197 - val_loss: 1.8579 - val_output1_loss: 1.6800 - val_output2_loss: 0.1779
# Epoch 125/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4242 - output1_loss: 1.9074 - output2_loss: 0.5168 - val_loss: 1.9092 - val_output1_loss: 1.7823 - val_output2_loss: 0.1269
# Epoch 126/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4543 - output1_loss: 1.9366 - output2_loss: 0.5178 - val_loss: 1.7920 - val_output1_loss: 1.7014 - val_output2_loss: 0.0905
# Epoch 127/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4367 - output1_loss: 1.9255 - output2_loss: 0.5112 - val_loss: 1.9740 - val_output1_loss: 1.7836 - val_output2_loss: 0.1903
# Epoch 128/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4344 - output1_loss: 1.9186 - output2_loss: 0.5158 - val_loss: 2.0064 - val_output1_loss: 1.7335 - val_output2_loss: 0.2729
# Epoch 129/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4261 - output1_loss: 1.9037 - output2_loss: 0.5224 - val_loss: 1.8502 - val_output1_loss: 1.6981 - val_output2_loss: 0.1521
# Epoch 130/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4151 - output1_loss: 1.8979 - output2_loss: 0.5172 - val_loss: 1.9837 - val_output1_loss: 1.7920 - val_output2_loss: 0.1917
# Epoch 131/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4259 - output1_loss: 1.9041 - output2_loss: 0.5218 - val_loss: 1.8806 - val_output1_loss: 1.7340 - val_output2_loss: 0.1466
# Epoch 132/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4205 - output1_loss: 1.8945 - output2_loss: 0.5260 - val_loss: 1.8241 - val_output1_loss: 1.6989 - val_output2_loss: 0.1252
# Epoch 133/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4229 - output1_loss: 1.9021 - output2_loss: 0.5208 - val_loss: 1.8108 - val_output1_loss: 1.7428 - val_output2_loss: 0.0680
# Epoch 134/500
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4127 - output1_loss: 1.8959 - output2_loss: 0.5168 - val_loss: 1.7840 - val_output1_loss: 1.6938 - val_output2_loss: 0.0902
# Epoch 135/500
# 673/673 [==============================] - ETA: 0s - loss: 2.4410 - output1_loss: 1.9242 - output2_loss: 0.5168Restoring model weights from the end of the best epoch: 115.
# 673/673 [==============================] - 5s 7ms/step - loss: 2.4410 - output1_loss: 1.9242 - output2_loss: 0.5168 - val_loss: 1.9196 - val_output1_loss: 1.7840 - val_output2_loss: 0.1356
# Epoch 135: early stopping
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
